# %% [markdown]
# # location analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os 
print(os.getcwd())  # เช็ก path ปัจจุบัน
# Out:
# d:\marketing\marketing_007\location_analysis

# %%
df_main = pd.read_csv('../Final3/df_mainlast.csv') 
df_main
# Out:
#                                                   name        lat        long  \
# 0                                  Cafe’ Amazon RM2076  13.992462  100.648220
# 1                                      ร้านกาแฟ อเมซอน  13.989384  100.634434
# 2    Café Amazon สาขา โครงการรังสิตสเตชั่น (สำนักงา...  14.007563  100.614831
# 3                      CAFÉ AMAZON รังสิต 200 ปี ซอย 4  13.989060  100.606208
# 4                             Café Amazon สาขาม.รังสิต  13.970512  100.630860
# ..                                                 ...        ...         ...
# 223                                        เจริญ คาเฟ่  13.986646  100.603027
# 224                             Malong Cafe & ChillBar  13.965698  100.596751
# 225                                   Buddy Cup Coffee  13.987673  100.608295
# 226                                        COFFEE CHAN  13.965428  100.596121
# 227                                  Tea & Coffee Home  13.987088  100.613803
#
#                                                    url  rating  comment  \
# 0    https://www.google.com/maps/place/Cafe%E2%80%9...     4.2      115
# 1    https://www.google.com/maps/place/%E0%B8%A3%E0...     4.4      103
# 2    https://www.google.com/maps/place/Caf%C3%A9+Am...     3.5       13
# 3    https://www.google.com/maps/place/CAF%C3%89+AM...     4.3       12
# 4    https://www.google.com/maps/place/Caf%C3%A9+Am...     3.5        6
# ..                                                 ...     ...      ...
# 223  https://www.google.com/maps/place/%E0%B9%80%E0...     5.0        5
# 224  https://www.google.com/maps/place/Malong+Cafe+...     4.7       26
# 225  https://www.google.com/maps/place/Buddy+Cup+Co...     4.3        9
# 226  https://www.google.com/maps/place/COFFEE+CHAN/...     4.7       26
# 227  https://www.google.com/maps/place/Tea+%26+Coff...     4.7       20
#
#                sal1  sal2 id_open_close_main id_customer_main  ...  \
# 0      ฿1-100 ต่อคน   7.0             oc_500           ci_500  ...
# 1      ฿1-100 ต่อคน   7.0             oc_501           ci_501  ...
# 2    ฿100-200 ต่อคน   5.0             oc_502           ci_502  ...
# 3      ฿1-100 ต่อคน   5.0             oc_503           ci_503  ...
# 4               NaN   NaN             oc_504           ci_504  ...
# ..              ...   ...                ...              ...  ...
# 223    ฿1-100 ต่อคน   5.0             oc_249           ci_249  ...
# 224  ฿200-300 ต่อคน   6.0             oc_250           ci_250  ...
# 225             NaN   NaN             oc_256           ci_256  ...
# 226    ฿1-100 ต่อคน   8.0             oc_258           ci_258  ...
# 227             NaN   NaN             oc_261           ci_261  ...
#
#     distance_rangsit distance_khlong_rangsit distance_lak_hok  distance_rmutt  \
# 0           5.750316                5.526942         6.700225        4.288353
# 1           4.259964                4.000615         5.225716        2.859694
# 2           2.868412                3.431994         5.222182        3.800549
# 3           1.222328                1.220953         2.970249        1.918096
# 4           4.460949                3.704490         4.173142        1.882750
# ..               ...                     ...              ...             ...
# 223         0.965577                0.791567         2.571594        1.867358
# 224         2.755512                1.729242         0.461525        2.016550
# 225         1.470166                1.295121         2.961421        1.689413
# 226         2.781655                1.767087         0.396549        2.090885
# 227         2.065918                1.793928         3.292555        1.521752
#
#      distance_nbu  distance_bu  distance_tu  distance_rsu  weighted_rating  \
# 0        2.545516     6.479161     9.992976      7.601018              NaN
# 1        4.071846     6.043252     9.726211      6.097600              NaN
# 2        6.185930     3.559212     7.263149      5.678762              NaN
# 3        7.078128     5.654628     9.252708      3.516978              NaN
# 4        5.291262     7.916160    11.637719      5.196244              NaN
# ..            ...          ...          ...           ...              ...
# 223      7.457365     5.971917     9.525066      3.084097         4.582184
# 224      8.781057     8.388002    11.888851      1.508041         4.599579
# 225      6.877951     5.784437     9.411094      3.580914         4.463498
# 226      8.855410     8.431685    11.924499      1.443738         4.599579
# 227      6.303633     5.830216     9.512763      4.018215         4.587529
#
#      amazon
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 223       0
# 224       0
# 225       0
# 226       0
# 227       0
#
# [228 rows x 23 columns]

# %%
df_main['zone'].unique()
# Out:
# array(['rungsit', 'krongone', 'rakhok'], dtype=object)

# %%
df_main.columns[-11:]
# Out:
# Index(['zone', 'distance_rangsit', 'distance_khlong_rangsit',
#        'distance_lak_hok', 'distance_rmutt', 'distance_nbu', 'distance_bu',
#        'distance_tu', 'distance_rsu', 'weighted_rating', 'amazon'],
#       dtype='object')

# %%
df_rakhok = df_main[df_main['zone'] == 'rakhok']

# %%
df_rakhok.head(2)
# Out:
#                               name        lat        long  \
# 17  คาเฟ่ อเมซอน ถนนนาวงประชาพัฒนา  13.959229  100.575686
# 18             Theme Cafe & Bistro  13.961911  100.605467
#
#                                                   url  rating  comment  \
# 17  https://www.google.com/maps/place/%E0%B8%84%E0...     4.3       76
# 18  https://www.google.com/maps/place/Theme+Cafe+%...     4.4       69
#
#             sal1  sal2 id_open_close_main id_customer_main  ...  \
# 17  ฿1-100 ต่อคน   9.0             oc_600           ci_600  ...
# 18           NaN   NaN               oc_1             ci_1  ...
#
#    distance_rangsit distance_khlong_rangsit distance_lak_hok  distance_rmutt  \
# 17         4.044298                3.453572         1.958418        4.391211
# 18         3.366392                2.276054         1.470299        1.554408
#
#     distance_nbu  distance_bu  distance_tu  distance_rsu  weighted_rating  \
# 17     11.154227     9.783467    12.978093      1.159600              NaN
# 18      8.126251     8.664852    12.271402      2.506534         4.434105
#
#     amazon
# 17       1
# 18       0
#
# [2 rows x 23 columns]

# %%
df_rakhok[['weighted_rating','distance_rsu']].corr()
# Out:
#                  weighted_rating  distance_rsu
# weighted_rating         1.000000      0.185452
# distance_rsu            0.185452      1.000000

# %%
plt.scatter(y='weighted_rating',x='distance_rsu',data=df_rakhok[['weighted_rating','distance_rsu']])
plt.xlabel('distance_rsu')
plt.ylabel('weighted_rating')
# Out:
# Text(0, 0.5, 'weighted_rating')

# %% [markdown]
# จะเห็นได้ว่า scatterplot weighted_rating vs distance rsu ไม่ว่าจะใกล้หรือจะไกล มันก็มี rating ที่สูงต่ำเหมือนกัน
# - cafe ใกล้ๆ rating ก็กระจายไม่แตกต่าง อาจเป็นเพราะว่า rating มี bias เนื่องจากคนไทยชอบคอมเม้นให้คะแนนดีๆ ไม่ค่อยให้ดาวน้อย
# - cafe ส่วนใหญ่กระจุกใกล้มหาลัย

# %%
df_rakhok[['weighted_rating','distance_rsu']].hist(figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'weighted_rating'}>,
#         <Axes: title={'center': 'distance_rsu'}>]], dtype=object)

# %% [markdown]
# กราฟทางขวาจะเห็นได้ว่า ส่วนมาก ร้าน cafe ตำบลนี้จะเปิดใกล้มอ

# %% [markdown]
# ยังไม่ชัด โชว์ maps

# %%
import pandas as pd
import folium
from folium import plugins
zone_colors = {
    'rungsit': 'red',
    'rakhok': 'blue',
    'krongone': 'green'
}
center_lat = 13.9731
center_long = 100.5892

m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

for idx, row in df_main.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,  
        color=zone_colors[row['zone']],
        fill=True,
        fill_color=zone_colors[row['zone']],
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
                Zone: {row['zone']}"
    ).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e4730f1b09614c7bdb4240bc19205a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e4730f1b09614c7bdb4240bc19205a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e4730f1b09614c7bdb4240bc19205a9 = L.map(
#                 &quot;map_3e4730f1b09614c7bdb4240bc19205a9&quot;,
#                 {
#                     center: [13.9731, 100.5892],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42c31d08e5f3742f500ab1b4860cf3ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42c31d08e5f3742f500ab1b4860cf3ae.addTo(map_3e4730f1b09614c7bdb4240bc19205a9);
#
#
#             var circle_marker_61e2df0ab0921141f2bcee5dee0a2fe7 = L.circleMarker(
#                 [13.9924622, 100.6482196],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: NaN, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e4730f1b09614c7bdb4240bc19205a9);
#
#
#         var popup_1920cab9c4a67e6a96310ed8cee30f4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_664071a8b1974fd9186323903e3ef3e6 = $(`&lt;div id=&quot;html_664071a8b1974fd9186323903e3ef3e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cafe’ Amazon RM2076&lt;br&gt;            W_Rating: nan&lt;br&gt;            n_comment: 115&lt;br&gt;                Zone: rungsit&lt;/div&gt;`)[0];
#                 popup_1920cab9c4a67e6a96310ed8cee30f4b.setContent(html_664071a8b1974fd9186323903e3ef3e6);
#
#
#
#         circle_marker_61e2df0ab0921141f2bcee5dee0a2fe7.bindPopup(popup_1920cab9c4a67e6a96310ed8cee30f4b)
#         ;
#
#
#
#
#             var circle_marker_f478d816b760864a6cb224a68e0c8ebe = L.circleMarker(
#                 [13.9893835, 100.6344337],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: NaN, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e4730f1b09614c7bdb4240bc19205a9);
#
#
#         var popup_1fec6cfde86db3b263690316ab6a2312 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd54ee32d78a3de4020f75d2d11407ae = $(`&lt;div id=&quot;html_cd54ee32d78a3de4020f75d2d11407ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ร้านกาแฟ อเมซอน&lt;br&gt;            W_Rating: nan&lt;br&gt;            n_comment: 103&lt;br&gt;                Zone: rungsit&lt;/div&gt;`)[0];
#                 popup_1fec6cfde86db3b263690316ab6a2312.setContent(html_cd54ee32d78a3de4020f75d2d11407ae);
#
#
#
#         circle_marker_f478d816b760864a6cb224a68e0c8ebe.bindPopup(popup_1fec6cfde86db3b263690316ab6a2312)
#         ;
#
#
#
#
#             var circle_marker_1a962c6889799ed1865f8e9b2268ed6e = L.circleMarker(
#                 [14.0075633, 100.6148308],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: NaN, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e4730f1b09614c7bdb4240bc19205a9);
#
#
#         var popup_855f1154ecb610cb700f0152c1a907f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb23d22477895cf8531f8707c684022a = $(`&lt;div id=&quot;html_fb23d22477895cf8531f8707c684022a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Café Amazon สาขา โครงการรังสิตสเตชั่น (สำนักงานใหญ่) (SD4278)&lt;br&gt;            W_Rating: nan&lt;br&gt;            n_comment: 13&lt;br&gt;                Zone: rungsit&lt;/div&gt;`)[0];
#                 popup_855f1154ecb610cb700f0152c1a907f5.setContent(html_fb23d22477895cf8531f8707c684022a);
#
#
#
#         circle_marker_1a962c6889799ed1865f8e9b2268ed6e.b

# %%
import pandas as pd
import folium

# จุดศูนย์กลาง: RSU
center_lat = 13.9670095
center_long = 100.582841

m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

# วาด marker ร้าน
for idx, row in df_rakhok.iterrows():
    if row['distance_rsu'] <= 1.5:
        color = 'blue'
    else:
        color = 'red'

    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
            Distance: {row['distance_rsu']:.2f} km"
    ).add_to(m)

# Marker RSU
folium.Marker(
    location=[center_lat, center_long],
    popup='RSU (ศูนย์กลาง)',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

# วงกลมรอบ RSU
folium.Circle(
    location=[center_lat, center_long],
    radius=1500,  # 2 km
    color='purple',
    fill=False,
    dash_array='5, 10',
    popup='รัศมี 1.5 km รอบ RSU'
).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7e0b008225cd75ca5431d41832500e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7e0b008225cd75ca5431d41832500e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7e0b008225cd75ca5431d41832500e4 = L.map(
#                 &quot;map_a7e0b008225cd75ca5431d41832500e4&quot;,
#                 {
#                     center: [13.9670095, 100.582841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_994fc437a09c4da14b280b3101f5e4b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_994fc437a09c4da14b280b3101f5e4b9.addTo(map_a7e0b008225cd75ca5431d41832500e4);
#
#
#             var circle_marker_43f6cac23a3528f3237b6c7635be6883 = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.682106239999996, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7e0b008225cd75ca5431d41832500e4);
#
#
#         var popup_aa553f715245bbf891640d57f523aa0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_526cc0d2746439ca680d2df8e2863535 = $(`&lt;div id=&quot;html_526cc0d2746439ca680d2df8e2863535&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.434105312&lt;br&gt;            n_comment: 69&lt;br&gt;            Distance: 2.51 km&lt;/div&gt;`)[0];
#                 popup_aa553f715245bbf891640d57f523aa0c.setContent(html_526cc0d2746439ca680d2df8e2863535);
#
#
#
#         circle_marker_43f6cac23a3528f3237b6c7635be6883.bindPopup(popup_aa553f715245bbf891640d57f523aa0c)
#         ;
#
#
#
#
#             var circle_marker_4a87cbe88fd20ae6815a222df6570c21 = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.025584839999997, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7e0b008225cd75ca5431d41832500e4);
#
#
#         var popup_6df2e6cbaaa2a109bacd3b49eb1a988a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae1ddde9e40eed7b6af14b4cf370daf3 = $(`&lt;div id=&quot;html_ae1ddde9e40eed7b6af14b4cf370daf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.751279242&lt;br&gt;            n_comment: 147&lt;br&gt;            Distance: 0.56 km&lt;/div&gt;`)[0];
#                 popup_6df2e6cbaaa2a109bacd3b49eb1a988a.setContent(html_ae1ddde9e40eed7b6af14b4cf370daf3);
#
#
#
#         circle_marker_4a87cbe88fd20ae6815a222df6570c21.bindPopup(popup_6df2e6cbaaa2a109bacd3b49eb1a988a)
#         ;
#
#
#
#
#             var circle_marker_fe4a462414f4d0b28483f15a3b7ac55c = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.121316539999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7e0b008225cd75ca5431d41832500e4);
#
#
#         var popup_34990b915ab7f7bc5938d104ca6ab088 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1cd93dd78fde8343dfe795998152c18 = $(`&lt;div id=&quot;html_e1cd93dd78fde8343dfe795998152c18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.656065827&lt;br&gt;            n_comment: 98&lt;br&gt;            Distance: 1.84 km&lt;/div&gt;`)[0];
#                 popup_34990b915ab7f7bc5938d104ca6ab088.setContent(html_e1cd93dd78fde8343dfe795998152c18);

# %%
m.save('cafes_rsu.html')

# %%
# ข้อมูลมหาวิทยาลัย: (ชื่อ, lat, long)

# %%
import pandas as pd
import folium
from folium import plugins

# โซนสี
zone_colors = {
    'rungsit': 'red',
    'rakhok': 'blue',
    'krongone': 'green'
}

# ตำแหน่งกลางของแผนที่
center_lat = 13.9731
center_long = 100.5892

# สร้างแผนที่
m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

# วาด marker ร้านอาหาร
for idx, row in df_main.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,  
        color=zone_colors[row['zone']],
        fill=True,
        fill_color=zone_colors[row['zone']],
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
            Zone: {row['zone']}"
    ).add_to(m)

# ข้อมูลมหาวิทยาลัย: (ชื่อ, lat, long)
universities = [
    ("RMUTT", 13.9734028,100.6136685),
    ("North Bangkok", 13.9975329,100.6712262),
    ("Bangkok University", 14.0395107,100.6127897),
    ("Thammasat (TU)", 14.0722696,100.6056305),
    ("RSU ", 13.9670095, 100.582841)
]

# วาดหมุดและวงกลมรัศมีรอบมหาวิทยาลัย
for name, lat, lon in universities:
    # ปักหมุดมหาวิทยาลัย
    folium.Marker(
        location=[lat, lon],
        popup=f"{name} University",
        icon=folium.Icon(color='purple', icon='university', prefix='fa')
    ).add_to(m)

    # วงกลมรอบมหาวิทยาลัย 1 km
    folium.Circle(
        location=[lat, lon],
        radius=1000,  # 1 km
        color='purple',
        fill=False,
        dash_array='5, 10',
        popup=f"1 km radius from {name}"
    ).add_to(m)

# เพิ่ม layer control
folium.LayerControl().add_to(m)

# แสดงแผนที่
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b98296052fda8719698f6a010822823 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b98296052fda8719698f6a010822823&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b98296052fda8719698f6a010822823 = L.map(
#                 &quot;map_1b98296052fda8719698f6a010822823&quot;,
#                 {
#                     center: [13.9731, 100.5892],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a0e85e48b82e773a85ef12c5d744ba8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a0e85e48b82e773a85ef12c5d744ba8.addTo(map_1b98296052fda8719698f6a010822823);
#
#
#             var circle_marker_36a90d57cf440a5f12865a3b2e03fb21 = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.682106239999996, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b98296052fda8719698f6a010822823);
#
#
#         var popup_4dd1f021dc75d3b48ecbc65492db8e7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0520c99e2778f24c149de35a72e9f61c = $(`&lt;div id=&quot;html_0520c99e2778f24c149de35a72e9f61c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.434105312&lt;br&gt;            n_comment: 69&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_4dd1f021dc75d3b48ecbc65492db8e7d.setContent(html_0520c99e2778f24c149de35a72e9f61c);
#
#
#
#         circle_marker_36a90d57cf440a5f12865a3b2e03fb21.bindPopup(popup_4dd1f021dc75d3b48ecbc65492db8e7d)
#         ;
#
#
#
#
#             var circle_marker_6434bb08af0c7c7d51ef45dd5c3932dc = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.025584839999997, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b98296052fda8719698f6a010822823);
#
#
#         var popup_c9148490c727d1125edfe119efaa392a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2629c764910157bc72549eaa3ceca520 = $(`&lt;div id=&quot;html_2629c764910157bc72549eaa3ceca520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.751279242&lt;br&gt;            n_comment: 147&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_c9148490c727d1125edfe119efaa392a.setContent(html_2629c764910157bc72549eaa3ceca520);
#
#
#
#         circle_marker_6434bb08af0c7c7d51ef45dd5c3932dc.bindPopup(popup_c9148490c727d1125edfe119efaa392a)
#         ;
#
#
#
#
#             var circle_marker_1c7687338168c5a859a6c1c7ef015f04 = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.121316539999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b98296052fda8719698f6a010822823);
#
#
#         var popup_9b1bd664f5c0b1cf1486bde54a57be4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_642c4dbcf02518a339933e7b6381ffd9 = $(`&lt;div id=&quot;html_642c4dbcf02518a339933e7b6381ffd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.656065827&lt;br&gt;            n_comment: 98&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_9b1bd664f5c0b1cf1486bde54a57be4b.setContent(html_642c4dbcf02518a339933e7b6381ffd9);

# %% [markdown]
# เราพบว่า รอบๆ รัศมี 1 กิโลเมตรจากตัวมหาลัย มักจะมี cafe ที่เปิดเยอะ ไม่ได้เป็นแค่มหาลัย แต่เป็น ห้างสรรพสินค้าด้วย

# %%
# Step 2: Competitor Density
from sklearn.neighbors import BallTree
import numpy as np

# แปลงพิกัดเป็น radians เพื่อใช้ metric='haversine'
coords_rad = np.deg2rad(df_main[['lat', 'long']].values)
tree = BallTree(coords_rad, metric='haversine')

# กำหนดรัศมี 1 กม. → r = 1/6371 (6371 = รัศมีโลกหน่วยกม.)
r = 1 / 6371  

# query_radius จะคืน array ของ counts (รวมตัวเองด้วย)
counts = tree.query_radius(coords_rad, r=r, count_only=True)

# สร้างคอลัมน์ใหม่ competitor_density = นับร้านรอบๆ (ไม่รวมตัวเอง)
df_main['competitor_density'] = counts - 1

# ดูสถิติสั้น ๆ
print(df_main['competitor_density'].describe())
# Out:
# count    263.000000
# mean      32.433460
# std       25.157867
# min        0.000000
# 25%       11.000000
# 50%       25.000000
# 75%       57.500000
# max       78.000000
# Name: competitor_density, dtype: float64

# %%
df_main['competitor_density']
# Out:
# 0       9
# 1      63
# 2      35
# 3      73
# 4      73
#        ..
# 258    58
# 259     8
# 260    27
# 261     8
# 262    11
# Name: competitor_density, Length: 263, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sc = plt.scatter(df_main['long'], df_main['lat'], 
                 c=df_main['competitor_density'], 
                 cmap='Reds', alpha=0.7)
plt.colorbar(sc, label='Competitor Density (within 1 km)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Step 2: Competitor Density Heatmap')
plt.show()

# %%
# List ของมหาวิทยาลัย
universities = [
    ("RMUTT", 13.9734028, 100.6136685),
    ("North Bangkok", 13.9975329, 100.6712262),
    ("Bangkok University", 14.0395107, 100.6127897),
    ("Thammasat (TU)", 14.0722696, 100.6056305),
    ("RSU", 13.9670095, 100.582841)
]

# สร้าง DataFrame
df_unis = pd.DataFrame(universities, columns=['name', 'lat', 'long'])
