# %% [markdown]
# # location analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os 
print(os.getcwd())  # เช็ก path ปัจจุบัน
# Out:
# d:\marketing\marketing_007\location_analysis

# %%
df_main = pd.read_csv('../Final/df_main_clean4.csv') 
df_main
# Out:
#                                                 name        lat        long  \
# 0                                Theme Cafe & Bistro  13.961911  100.605467
# 1                           Shelter specialty coffee  13.962536  100.585268
# 2    ภูมิใจเสนอ Poomjai Saner café & coworking space  13.965177  100.599799
# 3                              ใบแมว คาเฟ่แมว รังสิต  13.963064  100.587933
# 4                                     Mori Cat Cafe’  13.965271  100.589427
# ..                                               ...        ...         ...
# 156                Owlvee Soft | Future Park Rangsit  13.989605  100.616846
# 157  พิซซ่าเตาดินสองไร่สโลว์ไลฟ์ฟาร์ม รังสิต คลองสาม  14.021239  100.675426
# 158                        ดอยมูเซอคอฟฟี่@ตลาดรังสิต  13.986671  100.613261
# 159                               NJ coffee มอรังสิต  13.964200  100.592048
# 160    Coffee World - Future Rangsit Triangle 1st Fl  13.987520  100.618070
#
#                                                    url  rating  comment  \
# 0    https://www.google.com/maps/place/Theme+Cafe+%...     4.4     69.0
# 1    https://www.google.com/maps/place/Shelter+spec...     4.8    147.0
# 2    https://www.google.com/maps/place/%E0%B8%A0%E0...     4.7     98.0
# 3    https://www.google.com/maps/place/%E0%B9%83%E0...     4.4     48.0
# 4    https://www.google.com/maps/place/Mori+Cat+Caf...     4.9    124.0
# ..                                                 ...     ...      ...
# 156  https://www.google.com/maps/place/Owlvee+Soft+...     4.0     12.0
# 157  https://www.google.com/maps/place/%E0%B8%9E%E0...     4.5     87.0
# 158  https://www.google.com/maps/place/%E0%B8%94%E0...     5.0      1.0
# 159  https://www.google.com/maps/place/NJ+coffee+%E...     3.0      2.0
# 160  https://www.google.com/maps/place/Coffee+World...     4.4     19.0
#
#                sal1  sal2 id_open_close_main id_customer_main  ...      zone  \
# 0               NaN   NaN               oc_1             ci_1  ...    rakhok
# 1    ฿100-200 ต่อคน  78.0               oc_2             ci_2  ...    rakhok
# 2    ฿100-200 ต่อคน  30.0               oc_3             ci_3  ...    rakhok
# 3    ฿100-200 ต่อคน  21.0               oc_4             ci_4  ...    rakhok
# 4    ฿100-200 ต่อคน  40.0               oc_5             ci_5  ...    rakhok
# ..              ...   ...                ...              ...  ...       ...
# 156    ฿1-100 ต่อคน   4.0             oc_166           ci_166  ...   rungsit
# 157  ฿200-300 ต่อคน  13.0             oc_167           ci_167  ...  krongone
# 158             NaN   NaN             oc_168           ci_168  ...   rungsit
# 159             NaN   NaN             oc_169           ci_169  ...    rakhok
# 160  ฿100-200 ต่อคน   9.0             oc_170           ci_170  ...   rungsit
#
#     distance_rangsit distance_khlong_rangsit  distance_lak_hok  \
# 0           3.366392                2.276054          1.470299
# 1           3.272303                2.506605          0.863776
# 2           2.854773                1.785755          0.793977
# 3           3.134911                2.305347          0.583634
# 4           2.859427                2.012612          0.336883
# ..               ...                     ...               ...
# 156         2.362460                2.206453          3.722446
# 157         9.332748                9.435511         10.860451
# 158         2.017449                1.722628          3.218512
# 159         2.932347                2.005592          0.195462
# 160         2.513549                2.243294          3.660618
#
#      weighted_rating  distance_tu  distance_bu  distance_rsu  distance_rmutt  \
# 0           4.444043    12.266204     8.665416      2.506661        1.407657
# 1           4.756838    12.343998     9.060216      0.562693        3.084442
# 2           4.663752    11.905411     8.384099      1.841222        1.555031
# 3           4.455901    12.244306     8.914008      0.703422        2.796505
# 4           4.830911    11.980292     8.631846      0.736623        2.556450
# ..               ...          ...          ...           ...             ...
# 156         4.389530     9.303625     5.567019      4.446680        1.925644
# 157         4.511626     9.646302     7.056047     11.668051        8.716595
# 158         4.560008     9.573760     5.876349      3.943481        1.527547
# 159         4.448758    12.067434     8.668582      1.041642        2.339458
# 160         4.488985     9.554117     5.809696      4.432644        1.751931
#
#      distance_nbu
# 0        8.094479
# 1       10.022374
# 2        8.470990
# 3        9.734848
# 4        9.491029
# ..            ...
# 156      5.889712
# 157      2.664788
# 158      6.327365
# 159      9.277241
# 160      5.800038
#
# [161 rows x 22 columns]

# %%
df_main['zone'].unique()
# Out:
# array(['rakhok', 'krongone', 'rungsit'], dtype=object)

# %%
df_main.columns[-10:]
# Out:
# Index(['zone', 'distance_rangsit', 'distance_khlong_rangsit',
#        'distance_lak_hok', 'weighted_rating', 'distance_tu', 'distance_bu',
#        'distance_rsu', 'distance_rmutt', 'distance_nbu'],
#       dtype='object')

# %%
df_rakhok = df_main[df_main['zone'] == 'rakhok']

# %%
df_rakhok.head(2)
# Out:
#                        name        lat        long  \
# 0       Theme Cafe & Bistro  13.961911  100.605467
# 1  Shelter specialty coffee  13.962536  100.585268
#
#                                                  url  rating  comment  \
# 0  https://www.google.com/maps/place/Theme+Cafe+%...     4.4     69.0
# 1  https://www.google.com/maps/place/Shelter+spec...     4.8    147.0
#
#              sal1  sal2 id_open_close_main id_customer_main  ...    zone  \
# 0             NaN   NaN               oc_1             ci_1  ...  rakhok
# 1  ฿100-200 ต่อคน  78.0               oc_2             ci_2  ...  rakhok
#
#   distance_rangsit distance_khlong_rangsit  distance_lak_hok  weighted_rating  \
# 0         3.366392                2.276054          1.470299         4.444043
# 1         3.272303                2.506605          0.863776         4.756838
#
#    distance_tu  distance_bu  distance_rsu  distance_rmutt  distance_nbu
# 0    12.266204     8.665416      2.506661        1.407657      8.094479
# 1    12.343998     9.060216      0.562693        3.084442     10.022374
#
# [2 rows x 22 columns]

# %%
df_rakhok[['weighted_rating','distance_rsu']].corr()
# Out:
#                  weighted_rating  distance_rsu
# weighted_rating         1.000000      0.221382
# distance_rsu            0.221382      1.000000

# %%
plt.scatter(y='weighted_rating',x='distance_rsu',data=df_rakhok[['weighted_rating','distance_rsu']])
plt.xlabel('distance_rsu')
plt.ylabel('weighted_rating')
# Out:
# Text(0, 0.5, 'weighted_rating')

# %% [markdown]
# จะเห็นได้ว่า scatterplot weighted_rating vs distance rsu ไม่ว่าจะใกล้หรือจะไกล มันก็มี rating ที่สูงต่ำเหมือนกัน
# - cafe ใกล้ๆ rating ก็กระจายไม่แตกต่าง อาจเป็นเพราะว่า rating มี bias เนื่องจากคนไทยชอบคอมเม้นให้คะแนนดีๆ ไม่ค่อยให้ดาวน้อย
# - cafe ส่วนใหญ่กระจุกใกล้มหาลัย

# %%
df_rakhok[['weighted_rating','distance_rsu']].hist(figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'weighted_rating'}>,
#         <Axes: title={'center': 'distance_rsu'}>]], dtype=object)

# %% [markdown]
# กราฟทางขวาจะเห็นได้ว่า ส่วนมาก ร้าน cafe ตำบลนี้จะเปิดใกล้มอ

# %% [markdown]
# ยังไม่ชัด โชว์ maps

# %%
import pandas as pd
import folium
from folium import plugins
zone_colors = {
    'rungsit': 'red',
    'rakhok': 'blue',
    'krongone': 'green'
}
center_lat = 13.9731
center_long = 100.5892

m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

for idx, row in df_main.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,  
        color=zone_colors[row['zone']],
        fill=True,
        fill_color=zone_colors[row['zone']],
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
                Zone: {row['zone']}"
    ).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0653ed74c0af1d2df5f945aae0da8f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0653ed74c0af1d2df5f945aae0da8f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0653ed74c0af1d2df5f945aae0da8f4 = L.map(
#                 &quot;map_c0653ed74c0af1d2df5f945aae0da8f4&quot;,
#                 {
#                     center: [13.9731, 100.5892],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_757286625d1b88bd03b9c3ffd775c254 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_757286625d1b88bd03b9c3ffd775c254.addTo(map_c0653ed74c0af1d2df5f945aae0da8f4);
#
#
#             var circle_marker_8d05d25cfc195815384f2a2994ad3f57 = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.880858279999995, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0653ed74c0af1d2df5f945aae0da8f4);
#
#
#         var popup_d18d6fc86c2e4c6d822f38d46c5d41d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f10dec496f22e3d52c059d7f317003c = $(`&lt;div id=&quot;html_6f10dec496f22e3d52c059d7f317003c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.444042914&lt;br&gt;            n_comment: 69.0&lt;br&gt;                Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_d18d6fc86c2e4c6d822f38d46c5d41d0.setContent(html_6f10dec496f22e3d52c059d7f317003c);
#
#
#
#         circle_marker_8d05d25cfc195815384f2a2994ad3f57.bindPopup(popup_d18d6fc86c2e4c6d822f38d46c5d41d0)
#         ;
#
#
#
#
#             var circle_marker_ef94cd822628f5a76062510a5cb92b5a = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.136751240000006, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0653ed74c0af1d2df5f945aae0da8f4);
#
#
#         var popup_82b65160eac7d7c560788479a533a4a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed72dc5b85f87fed45f9ba793b03ae24 = $(`&lt;div id=&quot;html_ed72dc5b85f87fed45f9ba793b03ae24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.756837562&lt;br&gt;            n_comment: 147.0&lt;br&gt;                Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_82b65160eac7d7c560788479a533a4a7.setContent(html_ed72dc5b85f87fed45f9ba793b03ae24);
#
#
#
#         circle_marker_ef94cd822628f5a76062510a5cb92b5a.bindPopup(popup_82b65160eac7d7c560788479a533a4a7)
#         ;
#
#
#
#
#             var circle_marker_374d4fd6014c403c23e130b3a9f060bb = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.275038820000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0653ed74c0af1d2df5f945aae0da8f4);
#
#
#         var popup_aadc688abb983bc43ae1e77d14b3fc88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51392515c50e81c196b76cd308d2d622 = $(`&lt;div id=&quot;html_51392515c50e81c196b76cd308d2d622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.663751941&lt;br&gt;            n_comment: 98.0&lt;br&gt;                Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_aadc688abb983bc43ae1e77d14b3fc88.setContent(html_51392515c50e81c196b76cd308d2d622);

# %%
import pandas as pd
import folium

# จุดศูนย์กลาง: RSU
center_lat = 13.9670095
center_long = 100.582841

m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

# วาด marker ร้าน
for idx, row in df_rakhok.iterrows():
    if row['distance_rsu'] <= 1.5:
        color = 'blue'
    else:
        color = 'red'

    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
            Distance: {row['distance_rsu']:.2f} km"
    ).add_to(m)

# Marker RSU
folium.Marker(
    location=[center_lat, center_long],
    popup='RSU (ศูนย์กลาง)',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

# วงกลมรอบ RSU
folium.Circle(
    location=[center_lat, center_long],
    radius=1500,  # 2 km
    color='purple',
    fill=False,
    dash_array='5, 10',
    popup='รัศมี 1.5 km รอบ RSU'
).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3866f91132beeb707555e41c9910805 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3866f91132beeb707555e41c9910805&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3866f91132beeb707555e41c9910805 = L.map(
#                 &quot;map_a3866f91132beeb707555e41c9910805&quot;,
#                 {
#                     center: [13.9670095, 100.582841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fadb161448891a0b39bb11846b14970 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1fadb161448891a0b39bb11846b14970.addTo(map_a3866f91132beeb707555e41c9910805);
#
#
#             var circle_marker_c0c4c24b214b1fe94bdbb25165b44eac = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.880858279999995, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a3866f91132beeb707555e41c9910805);
#
#
#         var popup_f15a00ade61a74ea01b37c0084a710ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e515be22a21a1d5436511db260b3383 = $(`&lt;div id=&quot;html_8e515be22a21a1d5436511db260b3383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.444042914&lt;br&gt;            n_comment: 69.0&lt;br&gt;            Distance: 2.51 km&lt;/div&gt;`)[0];
#                 popup_f15a00ade61a74ea01b37c0084a710ec.setContent(html_8e515be22a21a1d5436511db260b3383);
#
#
#
#         circle_marker_c0c4c24b214b1fe94bdbb25165b44eac.bindPopup(popup_f15a00ade61a74ea01b37c0084a710ec)
#         ;
#
#
#
#
#             var circle_marker_674f30810535c8b6a13c4149ad5819d0 = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.136751240000006, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a3866f91132beeb707555e41c9910805);
#
#
#         var popup_5a01856ecc59c58254004b1082e12ae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51fcd59d90bd036c453eedfa75e8d12c = $(`&lt;div id=&quot;html_51fcd59d90bd036c453eedfa75e8d12c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.756837562&lt;br&gt;            n_comment: 147.0&lt;br&gt;            Distance: 0.56 km&lt;/div&gt;`)[0];
#                 popup_5a01856ecc59c58254004b1082e12ae2.setContent(html_51fcd59d90bd036c453eedfa75e8d12c);
#
#
#
#         circle_marker_674f30810535c8b6a13c4149ad5819d0.bindPopup(popup_5a01856ecc59c58254004b1082e12ae2)
#         ;
#
#
#
#
#             var circle_marker_1722afa691544f2f463258132806501c = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.275038820000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a3866f91132beeb707555e41c9910805);
#
#
#         var popup_eade1cffee0f7d9d4ffdff3172d0f2ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39bc019247e44b7fffda4896312495d7 = $(`&lt;div id=&quot;html_39bc019247e44b7fffda4896312495d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.663751941&lt;br&gt;            n_comment: 98.0&lt;br&gt;            Distance: 1.84 km&lt;/div&gt;`)[0];
#                 popup_eade1cffee0f7d9d4ffdff3172d0f2ff.setContent(html_39bc019247e44b7fffda4896312495d7

# %%
m.save('cafes_rsu.html')

# %%
# ข้อมูลมหาวิทยาลัย: (ชื่อ, lat, long)

# %%
import pandas as pd
import folium
from folium import plugins

# โซนสี
zone_colors = {
    'rungsit': 'red',
    'rakhok': 'blue',
    'krongone': 'green'
}

# ตำแหน่งกลางของแผนที่
center_lat = 13.9731
center_long = 100.5892

# สร้างแผนที่
m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

# วาด marker ร้านอาหาร
for idx, row in df_main.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,  
        color=zone_colors[row['zone']],
        fill=True,
        fill_color=zone_colors[row['zone']],
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
            Zone: {row['zone']}"
    ).add_to(m)

# ข้อมูลมหาวิทยาลัย: (ชื่อ, lat, long)
universities = [
    ("RMUTT", 13.9734028,100.6136685),
    ("North Bangkok", 13.9975329,100.6712262),
    ("Bangkok University", 14.0395107,100.6127897),
    ("Thammasat (TU)", 14.0722696,100.6056305),
    ("RSU ", 13.9670095, 100.582841)
]

# วาดหมุดและวงกลมรัศมีรอบมหาวิทยาลัย
for name, lat, lon in universities:
    # ปักหมุดมหาวิทยาลัย
    folium.Marker(
        location=[lat, lon],
        popup=f"{name} University",
        icon=folium.Icon(color='purple', icon='university', prefix='fa')
    ).add_to(m)

    # วงกลมรอบมหาวิทยาลัย 1 km
    folium.Circle(
        location=[lat, lon],
        radius=1000,  # 1 km
        color='purple',
        fill=False,
        dash_array='5, 10',
        popup=f"1 km radius from {name}"
    ).add_to(m)

# เพิ่ม layer control
folium.LayerControl().add_to(m)

# แสดงแผนที่
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ba48505574cab3967df17a346ec5bbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ba48505574cab3967df17a346ec5bbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ba48505574cab3967df17a346ec5bbc = L.map(
#                 &quot;map_3ba48505574cab3967df17a346ec5bbc&quot;,
#                 {
#                     center: [13.9731, 100.5892],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29cc4f4beef3f5fab82f6aadf77c8598 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29cc4f4beef3f5fab82f6aadf77c8598.addTo(map_3ba48505574cab3967df17a346ec5bbc);
#
#
#             var circle_marker_59392d495dafdc556ed86986fc436757 = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.880858279999995, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3ba48505574cab3967df17a346ec5bbc);
#
#
#         var popup_078a21b731d0f32c362456e4a01962d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52bd6c2bd0fbb15908138cc757c96acd = $(`&lt;div id=&quot;html_52bd6c2bd0fbb15908138cc757c96acd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.444042914&lt;br&gt;            n_comment: 69.0&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_078a21b731d0f32c362456e4a01962d5.setContent(html_52bd6c2bd0fbb15908138cc757c96acd);
#
#
#
#         circle_marker_59392d495dafdc556ed86986fc436757.bindPopup(popup_078a21b731d0f32c362456e4a01962d5)
#         ;
#
#
#
#
#             var circle_marker_ccceaeb4cc55275532272bf90742460c = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.136751240000006, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3ba48505574cab3967df17a346ec5bbc);
#
#
#         var popup_75872aea4958804a9e8b234a68e24fcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49317cee49c2c41b16f4cc526078bd3d = $(`&lt;div id=&quot;html_49317cee49c2c41b16f4cc526078bd3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.756837562&lt;br&gt;            n_comment: 147.0&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_75872aea4958804a9e8b234a68e24fcb.setContent(html_49317cee49c2c41b16f4cc526078bd3d);
#
#
#
#         circle_marker_ccceaeb4cc55275532272bf90742460c.bindPopup(popup_75872aea4958804a9e8b234a68e24fcb)
#         ;
#
#
#
#
#             var circle_marker_cb9001a5bd768465787f1e80a8b380cb = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.275038820000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3ba48505574cab3967df17a346ec5bbc);
#
#
#         var popup_6701a4aebe9153c0029d3f1666a31d46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d66b81dd9b93f4514f14feefcc503ea3 = $(`&lt;div id=&quot;html_d66b81dd9b93f4514f14feefcc503ea3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.663751941&lt;br&gt;            n_comment: 98.0&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_6701a4aebe9153c0029d3f1666a31d46.setContent(html_d66b81dd9b93f4514f14feefcc503ea3);

# %% [markdown]
# เราพบว่า รอบๆ รัศมี 1 กิโลเมตรจากตัวมหาลัย มักจะมี cafe ที่เปิดเยอะ ไม่ได้เป็นแค่มหาลัย แต่เป็น ห้างสรรพสินค้าด้วย
