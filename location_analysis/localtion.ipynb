# %% [markdown]
# # location analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os 
print(os.getcwd())  # เช็ก path ปัจจุบัน
# Out:
# d:\marketing\marketing_007\location_analysis

# %%
df_main = pd.read_csv('../Final/df_main_clean4.csv') 
df_main
# Out:
#                                                 name        lat        long  \
# 0                                Theme Cafe & Bistro  13.961911  100.605467
# 1                           Shelter specialty coffee  13.962536  100.585268
# 2    ภูมิใจเสนอ Poomjai Saner café & coworking space  13.965177  100.599799
# 3                              ใบแมว คาเฟ่แมว รังสิต  13.963064  100.587933
# 4                                     Mori Cat Cafe’  13.965271  100.589427
# ..                                               ...        ...         ...
# 156                Owlvee Soft | Future Park Rangsit  13.989605  100.616846
# 157  พิซซ่าเตาดินสองไร่สโลว์ไลฟ์ฟาร์ม รังสิต คลองสาม  14.021239  100.675426
# 158                        ดอยมูเซอคอฟฟี่@ตลาดรังสิต  13.986671  100.613261
# 159                               NJ coffee มอรังสิต  13.964200  100.592048
# 160    Coffee World - Future Rangsit Triangle 1st Fl  13.987520  100.618070
#
#                                                    url  rating  comment  \
# 0    https://www.google.com/maps/place/Theme+Cafe+%...     4.4     69.0
# 1    https://www.google.com/maps/place/Shelter+spec...     4.8    147.0
# 2    https://www.google.com/maps/place/%E0%B8%A0%E0...     4.7     98.0
# 3    https://www.google.com/maps/place/%E0%B9%83%E0...     4.4     48.0
# 4    https://www.google.com/maps/place/Mori+Cat+Caf...     4.9    124.0
# ..                                                 ...     ...      ...
# 156  https://www.google.com/maps/place/Owlvee+Soft+...     4.0     12.0
# 157  https://www.google.com/maps/place/%E0%B8%9E%E0...     4.5     87.0
# 158  https://www.google.com/maps/place/%E0%B8%94%E0...     5.0      1.0
# 159  https://www.google.com/maps/place/NJ+coffee+%E...     3.0      2.0
# 160  https://www.google.com/maps/place/Coffee+World...     4.4     19.0
#
#                sal1  sal2 id_open_close_main id_customer_main  ...      zone  \
# 0               NaN   NaN               oc_1             ci_1  ...    rakhok
# 1    ฿100-200 ต่อคน  78.0               oc_2             ci_2  ...    rakhok
# 2    ฿100-200 ต่อคน  30.0               oc_3             ci_3  ...    rakhok
# 3    ฿100-200 ต่อคน  21.0               oc_4             ci_4  ...    rakhok
# 4    ฿100-200 ต่อคน  40.0               oc_5             ci_5  ...    rakhok
# ..              ...   ...                ...              ...  ...       ...
# 156    ฿1-100 ต่อคน   4.0             oc_166           ci_166  ...   rungsit
# 157  ฿200-300 ต่อคน  13.0             oc_167           ci_167  ...  krongone
# 158             NaN   NaN             oc_168           ci_168  ...   rungsit
# 159             NaN   NaN             oc_169           ci_169  ...    rakhok
# 160  ฿100-200 ต่อคน   9.0             oc_170           ci_170  ...   rungsit
#
#     distance_rangsit distance_khlong_rangsit  distance_lak_hok  \
# 0           3.366392                2.276054          1.470299
# 1           3.272303                2.506605          0.863776
# 2           2.854773                1.785755          0.793977
# 3           3.134911                2.305347          0.583634
# 4           2.859427                2.012612          0.336883
# ..               ...                     ...               ...
# 156         2.362460                2.206453          3.722446
# 157         9.332748                9.435511         10.860451
# 158         2.017449                1.722628          3.218512
# 159         2.932347                2.005592          0.195462
# 160         2.513549                2.243294          3.660618
#
#      weighted_rating  distance_tu  distance_bu  distance_rsu  distance_rmutt  \
# 0           4.444043    12.266204     8.665416      2.506661        1.407657
# 1           4.756838    12.343998     9.060216      0.562693        3.084442
# 2           4.663752    11.905411     8.384099      1.841222        1.555031
# 3           4.455901    12.244306     8.914008      0.703422        2.796505
# 4           4.830911    11.980292     8.631846      0.736623        2.556450
# ..               ...          ...          ...           ...             ...
# 156         4.389530     9.303625     5.567019      4.446680        1.925644
# 157         4.511626     9.646302     7.056047     11.668051        8.716595
# 158         4.560008     9.573760     5.876349      3.943481        1.527547
# 159         4.448758    12.067434     8.668582      1.041642        2.339458
# 160         4.488985     9.554117     5.809696      4.432644        1.751931
#
#      distance_nbu
# 0        8.094479
# 1       10.022374
# 2        8.470990
# 3        9.734848
# 4        9.491029
# ..            ...
# 156      5.889712
# 157      2.664788
# 158      6.327365
# 159      9.277241
# 160      5.800038
#
# [161 rows x 22 columns]

# %%
df_main['zone'].unique()
# Out:
# array(['rakhok', 'krongone', 'rungsit'], dtype=object)

# %%
df_main.columns[-10:]
# Out:
# Index(['zone', 'distance_rangsit', 'distance_khlong_rangsit',
#        'distance_lak_hok', 'weighted_rating', 'distance_tu', 'distance_bu',
#        'distance_rsu', 'distance_rmutt', 'distance_nbu'],
#       dtype='object')

# %%
df_rakhok = df_main[df_main['zone'] == 'rakhok']

# %%
df_rakhok.head(2)
# Out:
#                        name        lat        long  \
# 0       Theme Cafe & Bistro  13.961911  100.605467
# 1  Shelter specialty coffee  13.962536  100.585268
#
#                                                  url  rating  comment  \
# 0  https://www.google.com/maps/place/Theme+Cafe+%...     4.4     69.0
# 1  https://www.google.com/maps/place/Shelter+spec...     4.8    147.0
#
#              sal1  sal2 id_open_close_main id_customer_main  ...    zone  \
# 0             NaN   NaN               oc_1             ci_1  ...  rakhok
# 1  ฿100-200 ต่อคน  78.0               oc_2             ci_2  ...  rakhok
#
#   distance_rangsit distance_khlong_rangsit  distance_lak_hok  weighted_rating  \
# 0         3.366392                2.276054          1.470299         4.444043
# 1         3.272303                2.506605          0.863776         4.756838
#
#    distance_tu  distance_bu  distance_rsu  distance_rmutt  distance_nbu
# 0    12.266204     8.665416      2.506661        1.407657      8.094479
# 1    12.343998     9.060216      0.562693        3.084442     10.022374
#
# [2 rows x 22 columns]

# %%
df_rakhok[['weighted_rating','distance_rsu']].corr()
# Out:
#                  weighted_rating  distance_rsu
# weighted_rating         1.000000      0.221382
# distance_rsu            0.221382      1.000000

# %%
plt.scatter(y='weighted_rating',x='distance_rsu',data=df_rakhok[['weighted_rating','distance_rsu']])
plt.xlabel('distance_rsu')
plt.ylabel('weighted_rating')
# Out:
# Text(0, 0.5, 'weighted_rating')

# %% [markdown]
# จะเห็นได้ว่า scatterplot weighted_rating vs distance rsu ไม่ว่าจะใกล้หรือจะไกล มันก็มี rating ที่สูงต่ำเหมือนกัน
# - cafe ใกล้ๆ rating ก็กระจายไม่แตกต่าง อาจเป็นเพราะว่า rating มี bias เนื่องจากคนไทยชอบคอมเม้นให้คะแนนดีๆ ไม่ค่อยให้ดาวน้อย
# - cafe ส่วนใหญ่กระจุกใกล้มหาลัย

# %%
df_rakhok[['weighted_rating','distance_rsu']].hist(figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'weighted_rating'}>,
#         <Axes: title={'center': 'distance_rsu'}>]], dtype=object)

# %% [markdown]
# กราฟทางขวาจะเห็นได้ว่า ส่วนมาก ร้าน cafe ตำบลนี้จะเปิดใกล้มอ

# %% [markdown]
# ยังไม่ชัด โชว์ maps

# %%
import pandas as pd
import folium
from folium import plugins
zone_colors = {
    'rungsit': 'red',
    'rakhok': 'blue',
    'krongone': 'green'
}
center_lat = 13.9731
center_long = 100.5892

m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

for idx, row in df_main.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,  
        color=zone_colors[row['zone']],
        fill=True,
        fill_color=zone_colors[row['zone']],
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
                Zone: {row['zone']}"
    ).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc79d474dc4e20f95c39b3327257709d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc79d474dc4e20f95c39b3327257709d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc79d474dc4e20f95c39b3327257709d = L.map(
#                 &quot;map_bc79d474dc4e20f95c39b3327257709d&quot;,
#                 {
#                     center: [13.9731, 100.5892],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4edd05314c820812f01bfc0e2c25c736 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4edd05314c820812f01bfc0e2c25c736.addTo(map_bc79d474dc4e20f95c39b3327257709d);
#
#
#             var circle_marker_764e9d77fafba35fb49262214d164391 = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.880858279999995, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc79d474dc4e20f95c39b3327257709d);
#
#
#         var popup_b1f62013811b0b322bbe018017daa457 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7dda9ffe36515bda846acb9bd665bdd = $(`&lt;div id=&quot;html_e7dda9ffe36515bda846acb9bd665bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.444042914&lt;br&gt;            n_comment: 69.0&lt;br&gt;                Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_b1f62013811b0b322bbe018017daa457.setContent(html_e7dda9ffe36515bda846acb9bd665bdd);
#
#
#
#         circle_marker_764e9d77fafba35fb49262214d164391.bindPopup(popup_b1f62013811b0b322bbe018017daa457)
#         ;
#
#
#
#
#             var circle_marker_5fd00162a99b5f1d8f88bdc147200ecb = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.136751240000006, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc79d474dc4e20f95c39b3327257709d);
#
#
#         var popup_83eb4b89530caad1fdbb520c3f28f770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d21f01ddcacd6fdc91bf02e8484952df = $(`&lt;div id=&quot;html_d21f01ddcacd6fdc91bf02e8484952df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.756837562&lt;br&gt;            n_comment: 147.0&lt;br&gt;                Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_83eb4b89530caad1fdbb520c3f28f770.setContent(html_d21f01ddcacd6fdc91bf02e8484952df);
#
#
#
#         circle_marker_5fd00162a99b5f1d8f88bdc147200ecb.bindPopup(popup_83eb4b89530caad1fdbb520c3f28f770)
#         ;
#
#
#
#
#             var circle_marker_0530cb79dd9a583aa50e6256032db7e6 = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.275038820000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc79d474dc4e20f95c39b3327257709d);
#
#
#         var popup_89b75f6ae63765a15b48841fb52657a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc92effab056691e2e1a88e47e6e474c = $(`&lt;div id=&quot;html_fc92effab056691e2e1a88e47e6e474c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.663751941&lt;br&gt;            n_comment: 98.0&lt;br&gt;                Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_89b75f6ae63765a15b48841fb52657a5.setContent(html_fc92effab056691e2e1a88e47e6e474c);

# %%
import pandas as pd
import folium

# จุดศูนย์กลาง: RSU
center_lat = 13.9670095
center_long = 100.582841

m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

# วาด marker ร้าน
for idx, row in df_rakhok.iterrows():
    if row['distance_rsu'] <= 1.5:
        color = 'blue'
    else:
        color = 'red'

    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
            Distance: {row['distance_rsu']:.2f} km"
    ).add_to(m)

# Marker RSU
folium.Marker(
    location=[center_lat, center_long],
    popup='RSU (ศูนย์กลาง)',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

# วงกลมรอบ RSU
folium.Circle(
    location=[center_lat, center_long],
    radius=1500,  # 2 km
    color='purple',
    fill=False,
    dash_array='5, 10',
    popup='รัศมี 1.5 km รอบ RSU'
).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1bde793ed4dcc732e5206d5881d014e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1bde793ed4dcc732e5206d5881d014e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1bde793ed4dcc732e5206d5881d014e = L.map(
#                 &quot;map_b1bde793ed4dcc732e5206d5881d014e&quot;,
#                 {
#                     center: [13.9670095, 100.582841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b9bbdb82b7aa2c620a3e851fa2ba10d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b9bbdb82b7aa2c620a3e851fa2ba10d.addTo(map_b1bde793ed4dcc732e5206d5881d014e);
#
#
#             var circle_marker_093894fd8558452c855e8b11d105ae03 = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.880858279999995, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1bde793ed4dcc732e5206d5881d014e);
#
#
#         var popup_db80590a33ef283677efc7c04102e85e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81ea571a6d9e9b235497e20532332bee = $(`&lt;div id=&quot;html_81ea571a6d9e9b235497e20532332bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.444042914&lt;br&gt;            n_comment: 69.0&lt;br&gt;            Distance: 2.51 km&lt;/div&gt;`)[0];
#                 popup_db80590a33ef283677efc7c04102e85e.setContent(html_81ea571a6d9e9b235497e20532332bee);
#
#
#
#         circle_marker_093894fd8558452c855e8b11d105ae03.bindPopup(popup_db80590a33ef283677efc7c04102e85e)
#         ;
#
#
#
#
#             var circle_marker_543ccd22670323431f056eac4db89235 = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.136751240000006, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1bde793ed4dcc732e5206d5881d014e);
#
#
#         var popup_f59dc24b44e0534f58a69710444030b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cf78ce495557b4628c1e43001a02b45 = $(`&lt;div id=&quot;html_0cf78ce495557b4628c1e43001a02b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.756837562&lt;br&gt;            n_comment: 147.0&lt;br&gt;            Distance: 0.56 km&lt;/div&gt;`)[0];
#                 popup_f59dc24b44e0534f58a69710444030b9.setContent(html_0cf78ce495557b4628c1e43001a02b45);
#
#
#
#         circle_marker_543ccd22670323431f056eac4db89235.bindPopup(popup_f59dc24b44e0534f58a69710444030b9)
#         ;
#
#
#
#
#             var circle_marker_bb1dcb6bab1de5f7da68c5f71613269c = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.275038820000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1bde793ed4dcc732e5206d5881d014e);
#
#
#         var popup_f5b2dc66240cc890fbd07917c4f2b4b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e234ceff8917546110cbff7a3465f4a = $(`&lt;div id=&quot;html_8e234ceff8917546110cbff7a3465f4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.663751941&lt;br&gt;            n_comment: 98.0&lt;br&gt;            Distance: 1.84 km&lt;/div&gt;`)[0];
#                 popup_f5b2dc66240cc890fbd07917c4f2b4b9.setContent(html_8e234ceff8917546110cbff7a3465f4a

# %%
m.save('cafes_rsu.html')

# %%
# ข้อมูลมหาวิทยาลัย: (ชื่อ, lat, long)

# %%
import pandas as pd
import folium
from folium import plugins

# โซนสี
zone_colors = {
    'rungsit': 'red',
    'rakhok': 'blue',
    'krongone': 'green'
}

# ตำแหน่งกลางของแผนที่
center_lat = 13.9731
center_long = 100.5892

# สร้างแผนที่
m = folium.Map(location=[center_lat, center_long], zoom_start=14, tiles='OpenStreetMap')

# วาด marker ร้านอาหาร
for idx, row in df_main.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=(row['weighted_rating'] - 4.0) * 20,  
        color=zone_colors[row['zone']],
        fill=True,
        fill_color=zone_colors[row['zone']],
        fill_opacity=0.7,
        popup=f"{row['name']}<br>\
            W_Rating: {row['weighted_rating']}<br>\
            n_comment: {row['comment']}<br>\
            Zone: {row['zone']}"
    ).add_to(m)

# ข้อมูลมหาวิทยาลัย: (ชื่อ, lat, long)
universities = [
    ("RMUTT", 13.973064,100.6139111),
    ("North Bangkok", 13.9975329,100.6712262),
    ("Bangkok University", 14.0395107,100.6127897),
    ("Thammasat (TU)", 14.0677029, 100.5987661),
    ("RSU ", 13.9670095, 100.582841)
]

# วาดหมุดและวงกลมรัศมีรอบมหาวิทยาลัย
for name, lat, lon in universities:
    # ปักหมุดมหาวิทยาลัย
    folium.Marker(
        location=[lat, lon],
        popup=f"{name} University",
        icon=folium.Icon(color='purple', icon='university', prefix='fa')
    ).add_to(m)

    # วงกลมรอบมหาวิทยาลัย 1 km
    folium.Circle(
        location=[lat, lon],
        radius=1000,  # 1 km
        color='purple',
        fill=False,
        dash_array='5, 10',
        popup=f"1 km radius from {name}"
    ).add_to(m)

# เพิ่ม layer control
folium.LayerControl().add_to(m)

# แสดงแผนที่
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65a581818e81e004f3e8cb416e788cfb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65a581818e81e004f3e8cb416e788cfb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65a581818e81e004f3e8cb416e788cfb = L.map(
#                 &quot;map_65a581818e81e004f3e8cb416e788cfb&quot;,
#                 {
#                     center: [13.9731, 100.5892],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29fac5aa2d5ff5b6b3e5fafb8a028164 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29fac5aa2d5ff5b6b3e5fafb8a028164.addTo(map_65a581818e81e004f3e8cb416e788cfb);
#
#
#             var circle_marker_b5e5de6549d39c36bde604115a5063e2 = L.circleMarker(
#                 [13.9619105, 100.6054672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.880858279999995, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_65a581818e81e004f3e8cb416e788cfb);
#
#
#         var popup_e0c3e5f49af34efac8351a36ca6c37b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_216868ab03563d56527fa6c687679107 = $(`&lt;div id=&quot;html_216868ab03563d56527fa6c687679107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theme Cafe &amp; Bistro&lt;br&gt;            W_Rating: 4.444042914&lt;br&gt;            n_comment: 69.0&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_e0c3e5f49af34efac8351a36ca6c37b2.setContent(html_216868ab03563d56527fa6c687679107);
#
#
#
#         circle_marker_b5e5de6549d39c36bde604115a5063e2.bindPopup(popup_e0c3e5f49af34efac8351a36ca6c37b2)
#         ;
#
#
#
#
#             var circle_marker_732e8bcbf32391173496cad0d3f91047 = L.circleMarker(
#                 [13.9625357, 100.5852678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.136751240000006, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_65a581818e81e004f3e8cb416e788cfb);
#
#
#         var popup_97193f3d9eca8170ab46a7fbb2bc1b5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_821e7f813d6260c290fb7166b47bb88e = $(`&lt;div id=&quot;html_821e7f813d6260c290fb7166b47bb88e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter specialty coffee&lt;br&gt;            W_Rating: 4.756837562&lt;br&gt;            n_comment: 147.0&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_97193f3d9eca8170ab46a7fbb2bc1b5e.setContent(html_821e7f813d6260c290fb7166b47bb88e);
#
#
#
#         circle_marker_732e8bcbf32391173496cad0d3f91047.bindPopup(popup_97193f3d9eca8170ab46a7fbb2bc1b5e)
#         ;
#
#
#
#
#             var circle_marker_fa4115e124fe7a05dd4d28cd55114c55 = L.circleMarker(
#                 [13.965177, 100.5997985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.275038820000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_65a581818e81e004f3e8cb416e788cfb);
#
#
#         var popup_39ca3ae1562f348affdd519efd8592f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3274f1afdecf4b80f515022744e51bc = $(`&lt;div id=&quot;html_a3274f1afdecf4b80f515022744e51bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ภูมิใจเสนอ Poomjai Saner café &amp; coworking space&lt;br&gt;            W_Rating: 4.663751941&lt;br&gt;            n_comment: 98.0&lt;br&gt;            Zone: rakhok&lt;/div&gt;`)[0];
#                 popup_39ca3ae1562f348affdd519efd8592f1.setContent(html_a3274f1afdecf4b80f515022744e51bc);

# %% [markdown]
# เราพบว่า รอบๆ รัศมี 1 กิโลเมตรจากตัวมหาลัย มักจะมี cafe ที่เปิดเยอะ ไม่ได้เป็นแค่มหาลัย แต่เป็น ห้างสรรพสินค้าด้วย
